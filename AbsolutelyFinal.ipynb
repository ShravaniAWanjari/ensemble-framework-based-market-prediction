# %%
import yfinance as yf
import numpy as np
import pandas as pd
from scipy.stats import wasserstein_distance
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from tqdm import tqdm
import seaborn as sns

# %%
# ======================
# 1. Data Preparation
# ======================
def load_data():
    """Load and preprocess S&P 500 data"""
    print("Downloading MSFT data...")
    data = yf.download("MSFT", start='2018-01-01',end='2024-01-01')
    data = data.copy()
    data.loc[:, "LogReturn"] = np.log(data["Close"] / data["Close"].shift(1))
    return data.dropna()

# %%
# ======================
# 2. Core Algorithm (Enhanced)
# ======================
def trend_augmented_distance(w1, w2):
    """Enhanced Wasserstein distance with trend component"""
    base_dist = wasserstein_distance(w1, w2)
    trend_diff = np.abs(np.sum(w1) - np.sum(w2)) * 0.3  # Weighted trend difference
    return base_dist + trend_diff

def compute_wasserstein_matrix(windows):
    """Compute normalized Wasserstein distance matrix with trend augmentation"""
    n = len(windows)
    dist_matrix = np.zeros((n, n))
    
    for i in tqdm(range(n), desc="Computing Wasserstein distances"):
        for j in range(i, n):
            if len(windows[i]) == 0 or len(windows[j]) == 0:
                dist_matrix[i,j] = np.inf
            else:
                try:
                    dist = trend_augmented_distance(windows[i], windows[j])
                    dist_matrix[i,j] = dist if not np.isnan(dist) else np.inf
                except:
                    dist_matrix[i,j] = np.inf
            dist_matrix[j,i] = dist_matrix[i,j]
    
    max_finite = np.max(dist_matrix[np.isfinite(dist_matrix)], initial=1.0)
    dist_matrix[~np.isfinite(dist_matrix)] = 10 * max_finite
    return dist_matrix / np.max(dist_matrix)


def detect_regimes(data, window_size=126, n_clusters=3):
    """Main regime detection function"""
    returns = data["LogReturn"].values
    windows = [returns[i:i+window_size] for i in range(len(returns)-window_size)]
    
    dist_matrix = compute_wasserstein_matrix(windows)
    kmeans = KMeans(n_clusters=n_clusters, random_state=42).fit(dist_matrix)
    regimes = kmeans.labels_
    
    # Label clusters based on characteristics
    cluster_stats = []
    for i in range(n_clusters):
        cluster_returns = [windows[j] for j in range(len(windows)) if regimes[j] == i]
        cumulative_return = np.mean([np.sum(r) for r in cluster_returns])  # Sum of returns
        mean_vol = np.mean([np.std(r) for r in cluster_returns])
        cluster_stats.append((cumulative_return, mean_vol))
    
    # Sort by cumulative return (not mean return)
    sorted_clusters = np.argsort([stat[0] for stat in cluster_stats])[::-1]
    
    # Initialize labels as Sideways by default
    regime_labels = np.array(["Sideways"] * len(regimes))
    
    # Assign Bull and Bear labels to the top and bottom clusters
    regime_labels[regimes == sorted_clusters[0]] = "Bull"
    regime_labels[regimes == sorted_clusters[-1]] = "Bear"
    
    # Post-processing thresholds
    for i in range(len(regime_labels)):
        total_return = np.sum(windows[i])
        if total_return > 0.15:  # Strong Bull threshold (15%+ cumulative)
            regime_labels[i] = "Bull"
        elif total_return < -0.15:  # Strong Bear threshold (-15%+ cumulative)
            regime_labels[i] = "Bear"
        elif -0.05 <= total_return <= 0.05:  # Explicit Sideways range
            regime_labels[i] = "Sideways"
    
    return regime_labels, windows, dist_matrix

# %%
# ======================
# 3. Visualization (Unchanged)
# ======================
def plot_regime_results(data, regime_labels, window_size):
    """Create price and returns plots with regime shading"""
    dates = data.index.to_numpy()
    price = data["Close"].values
    
    fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(16, 10), gridspec_kw={'height_ratios': [2, 1]})
    
    # Price plot
    ax1.plot(dates, price, color='black', lw=1)
    colors = {'Bull': 'green', 'Bear': 'red', 'Sideways': 'gray'}
    for i, label in enumerate(regime_labels):
        start = dates[i]
        end = dates[i + window_size]
        ax1.axvspan(start, end, color=colors[label], alpha=0.1)
    ax1.set_title(f"{data.index.name} with {window_size}-Day Regimes", fontsize=14)
    ax1.set_ylabel("Price", fontsize=12)
    
    # Returns plot
    for i, label in enumerate(regime_labels):
        start = i + window_size
        end = start + 1 if i < len(regime_labels)-1 else len(data)
        ax2.scatter(dates[start:end], data["LogReturn"].iloc[start:end], 
                   color=colors[label], s=5, alpha=0.5, label=label if i == 0 else "")
    ax2.set_title("Daily Log Returns by Regime", fontsize=14)
    ax2.set_ylabel("Log Returns", fontsize=12)
    
    # Formatting
    for ax in [ax1, ax2]:
        ax.xaxis.set_major_locator(mdates.YearLocator(5))
        ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y"))
        ax.grid(True, linestyle='--', alpha=0.5)
    ax2.legend()
    plt.tight_layout()
    plt.savefig(f'regimes_{window_size}days.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
def hyperparameter_study(data, h1_options, h2_ratios, n_runs=100):
    """Parameter sensitivity analysis with robust validation"""
    results = []
    
    for h1 in tqdm(h1_options, desc="Window Sizes"):
        for h2_ratio in h2_ratios:
            h2 = int(h1 * h2_ratio)
            row = {'h1': h1, 'h2': f"{h2} ({int(h2_ratio*100)}%)"}
            
            for period_name, period_len in [('1_year', 252), ('2_years', 504)]:
                period_data = data.iloc[:period_len]
                
                accuracies = []
                inter_dists = []
                valid_runs = 0
                
                while valid_runs < n_runs:
                    try:
                        offset = np.random.randint(0, h2)
                        windows = [period_data["LogReturn"].iloc[offset+i:offset+i+h1].values 
                                  for i in range(0, len(period_data)-h1-offset, h2)]
                        
                        if len(windows) < 4:  # Need at least 4 windows for 3 clusters
                            continue
                            
                        dist_matrix = compute_wasserstein_matrix(windows)
                        kmeans = KMeans(n_clusters=3).fit(dist_matrix)
                        
                        # Calculate inter-centroid distance (always works)
                        centroids = [windows[np.argmin(c)] for c in kmeans.cluster_centers_]
                        curr_dists = []
                        for i in range(3):
                            for j in range(i+1, 3):
                                curr_dists.append(trend_augmented_distance(centroids[i], centroids[j]))
                        avg_inter_dist = np.mean(curr_dists)
                        inter_dists.append(avg_inter_dist)
                        
                        # Use alternative validation when silhouette fails
                        if len(windows) > 3 and len(set(kmeans.labels_)) == 3:
                            try:
                                sil_score = silhouette_score(dist_matrix, kmeans.labels_)
                                accuracies.append(sil_score)
                            except:
                                # Fallback: Use normalized inter-cluster distance
                                norm_score = avg_inter_dist / np.mean(dist_matrix)
                                accuracies.append(norm_score)
                        else:
                            # Use normalized inter-cluster distance
                            norm_score = avg_inter_dist / np.mean(dist_matrix)
                            accuracies.append(norm_score)
                            
                        valid_runs += 1
                            
                    except Exception as e:
                        continue
                
                if accuracies:
                    row.update({
                        f"{period_name}_median": np.median(accuracies) * 100,
                        f"{period_name}_max": np.max(accuracies) * 100,
                        f"{period_name}_max_inter": np.max(inter_dists) * 100
                    })
            
            # Full dataset analysis
            try:
                full_windows = [data["LogReturn"].iloc[i:i+h1].values 
                              for i in range(0, len(data)-h1, h2)]
                if len(full_windows) >= 4:
                    dist_matrix = compute_wasserstein_matrix(full_windows)
                    kmeans = KMeans(n_clusters=3).fit(dist_matrix)
                    
                    # Calculate inter-centroid distance
                    centroids = [full_windows[np.argmin(c)] for c in kmeans.cluster_centers_]
                    inter_dists = []
                    for i in range(3):
                        for j in range(i+1, 3):
                            inter_dists.append(trend_augmented_distance(centroids[i], centroids[j]))
                    avg_inter_dist = np.mean(inter_dists)
                    
                    # Try silhouette score, fallback to normalized distance
                    if len(full_windows) > 3 and len(set(kmeans.labels_)) == 3:
                        try:
                            sil_score = silhouette_score(dist_matrix, kmeans.labels_) * 100
                            row['20_years_median'] = sil_score
                        except:
                            row['20_years_median'] = (avg_inter_dist / np.mean(dist_matrix)) * 100
                    else:
                        row['20_years_median'] = (avg_inter_dist / np.mean(dist_matrix)) * 100
                    
                    row['20_years_max_inter'] = np.max(inter_dists) * 100
                    
            except Exception as e:
                print(f"Error in full dataset analysis: {str(e)}")
                continue
            
            results.append(row)
    
    return pd.DataFrame(results)


def plot_hyperparameter_results(results_df):
    """Visualize parameter sensitivity"""
    plt.figure(figsize=(14, 6))
    sns.heatmap(
        results_df.pivot(index='h1', columns='h2', values='20_years_median'),
        annot=True, fmt=".1f", cmap="YlGnBu", cbar_kws={'label': 'Median Accuracy (%)'}
    )
    plt.title("Clustering Accuracy by Window Size (h1) and Offset (h2)")
    plt.xlabel("Offset (h2 as % of h1)")
    plt.ylabel("Window Size (h1)")
    plt.tight_layout()
    plt.savefig('hyperparameter_heatmap.png', dpi=300)
    plt.show()

# %%
data = load_data()  
data.index.name = "MSFT"  # For plot titles
# Out:
# Downloading MSFT data...
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
print("\nRunning enhanced regime detection...")
regime_labels, windows, _ = detect_regimes(data, window_size=126)  # 6-month windows
plot_regime_results(data, regime_labels, window_size=126)
    
print("\nRunning optimized hyperparameter study...")
param_results = hyperparameter_study(
    data,
        h1_options=[63, 126, 189],  # Test quarterly, semi-annual, ~8-month
        h2_ratios=[0.3, 0.5],       # Moderate overlap
        n_runs=100
)
# Out:
# Running enhanced regime detection...
# Computing Wasserstein distances: 100%|██████████| 1382/1382 [00:26<00:00, 52.10it/s]
# Running optimized hyperparameter study...
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 3544.94it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 3676.58it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 2750.36it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1999.95it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2844.75it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 3334.10it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 2594.32it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2906.86it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 2481.84it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 2471.86it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 3659.66it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 2693.99it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2454.96it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1890.77it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 
/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 2000.86it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1998.95it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 2000.38it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3997.43it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3999.34it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3785.47it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1994.20it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1937.55it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3060.42it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 4099.00it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3999.34it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 4005.06it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 2001.82it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 4000.29it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1999.67it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3970.94it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3998.38it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1997.53it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1997.76it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3994.58it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3982.25it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 2875.27it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 4006.98it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3954.09it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 2292.91it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<?, ?it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1844.46it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1623.03it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 4003.15it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 4006.02it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3998.38it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3966.24it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3996.48it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1991.60it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3992.67it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1991.12it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 4006.98it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3218.96it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 2003.73it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1999.67it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1971.93it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1988.06it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1995.15it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 2002.77it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3116.70it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1939.34it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1685.64it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3997.43it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1671.70it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3968.12it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 2656.72it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3999.34it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 4001.24it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1647.25it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1990.89it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 2667.28it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 2185.67it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 2538.54it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 4001.24it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1996.81it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1997.76it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3994.58it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 2001.10it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1995.39it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3986.03it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3999.34it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1993.02it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 2000.14it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1388.84it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3102.30it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1997.05it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1700.34it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 1977.28it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3047.63it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 3996.48it/s]
# Computing Wasserstein distances: 100%|██████████| 4/4 [00:00<00:00, 2001.10it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1930.10it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2306.59it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 2200.58it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1998.43it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1995.10it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1994.63it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1999.67it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 2199.95it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 2201.21it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2845.53it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1667.65it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 1375.10it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1652.73it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 2739.58it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2000.24it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 2201.10it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1629.81it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1999.76it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2496.02it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1999.67it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 2200.05it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2499.29it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2498.99it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1996.05it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2288.47it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2500.03it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2443.09it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1869.54it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2500.63it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1800.36it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 1568.39it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1534.35it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1655.99it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1834.22it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 2749.38it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2498.84it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2435.01it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2000.05it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2500.18it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1630.82it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1933.66it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2500.48it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2500.03it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2501.37it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1934.64it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2494.38it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2500.33it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2501.08it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 1821.59it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2501.67it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1999.67it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1998.91it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 1834.27it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2982.30it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1828.94it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2000.62it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1569.72it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2150.59it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2499.44it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 2173.93it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 1834.05it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1667.32it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 2567.04it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1666.59it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2393.19it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1664.34it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2000.81it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 1833.03it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2499.14it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1432.53it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2001.10it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1661.44it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1971.19it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2498.10it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2001.48it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1715.25it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1957.03it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1666.66it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2453.81it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1845.68it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2259.86it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2500.33it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1833.01it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1997.86it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2500.18it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 2197.02it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 1833.17it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2002.91it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1668.18it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2086.20it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2262.30it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1841.46it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2000.14it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1979.75it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 1998.85it/s]
# Computing Wasserstein distances: 100%|██████████| 11/11 [00:00<00:00, 3005.10it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1725.77it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 1593.64it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 2318.06it/s]
# Computing Wasserstein distances: 100%|██████████| 10/10 [00:00<00:00, 3326.17it/s]
# Computing Wasserstein distances: 100%|██████████| 38/38 [00:00<00:00, 738.15it/s]

# %%
final_table = param_results.round(1)
print("\nOptimized Hyperparameter Results:")
print(final_table.to_markdown(index=False))
final_table.to_latex("hyperparameter_results.tex", index=False)
plot_hyperparameter_results(final_table)
    
print("\nEnhanced analysis complete! Files saved:")
print("- regimes_126days.png")
print("- hyperparameter_heatmap.png")
print("- hyperparameter_results.tex")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 final_table = param_results.round(1)
#       2 print("\nOptimized Hyperparameter Results:")
#       3 print(final_table.to_markdown(index=False))
#
# NameError: name 'param_results' is not defined
